# %% [markdown]
# я проделываю эту работу дважды, потому что первый файл я случайно дропнула не сохранив

# %% [markdown]
# цель работы: провести анализ выбранного датасета и описать каждый пункт
# ход работы:

# %%
import pandas as pd

terraria = pd.read_csv("Terraria .csv")

terraria
# Out:
#                    NAME     CLASS GAME PROGRESSION  DPS (SINGLE TARGET)  \
# 0                Zenith     Melee    Post-Moonlord                 4800
# 1            Last Prism      Mage    Post-Moonlord                 3657
# 2            Star Wrath     Melee    Post-Moonlord                 2700
# 3             Terrarian     Melee    Post-Moonlord                 2200
# 4              Meowmere     Melee    Post-Moonlord                 2100
# ..                  ...       ...              ...                  ...
# 390         Paper Plane    Ranger         Pre-Boss                   14
# 391         Finch Staff  Summoner         Pre-Boss                   10
# 392      Flameburst Rod  Summoner         Pre-Boss                    8
# 393         Flinx Staff  Summoner         Pre-Boss                    8
# 394  Lightning Aura Rod  Summoner         Pre-Boss                    8
#
#      DPS (MULTI TARGET)  DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# ...

# %% [markdown]
# 1) вывела весь датасет

# %%
terraria.shape
# Out:
# (395, 8)

# %% [markdown]
# 2) тут вывела размерность датасета

# %%
terraria.columns
# Out:
# Index(['NAME', 'CLASS', 'GAME PROGRESSION', 'DPS (SINGLE TARGET)',
#        'DPS (MULTI TARGET)', 'DPS (SINGLE TARGET + PROYECTILE ONLY)',
#        'DPS (MULTI TARGET + PROYECTILE ONLY)', 'OBSERVATIONS'],
#       dtype='object')

# %% [markdown]
# 3) тут вывела все столбцы датасета

# %%
terraria.nunique()
# Out:
# NAME                                     395
# CLASS                                      4
# GAME PROGRESSION                          16
# DPS (SINGLE TARGET)                      165
# DPS (MULTI TARGET)                       156
# DPS (SINGLE TARGET + PROYECTILE ONLY)     15
# DPS (MULTI TARGET + PROYECTILE ONLY)      17
# OBSERVATIONS                              34
# dtype: int64

# %% [markdown]
# 4) тут удалось вывести число уникальных значений в каждом столбце датасета

# %%
terraria[terraria['DPS (SINGLE TARGET)']< 100]
# Out:
#                      NAME     CLASS GAME PROGRESSION  DPS (SINGLE TARGET)  \
# 232               Bee Gun      Mage    Post-QueenBee                   95
# 233           Dart Pistol    Ranger         Post-WoF                   90
# 234       Enchanted Sword     Melee         Pre-Boss                   90
# 235  Explosive Trap Staff  Summoner       Post-Golem                   90
# 236           Firecracker  Summoner         Post-WoF                   90
# ..                    ...       ...              ...                  ...
# 390           Paper Plane    Ranger         Pre-Boss                   14
# 391           Finch Staff  Summoner         Pre-Boss                   10
# 392        Flameburst Rod  Summoner         Pre-Boss                    8
# 393           Flinx Staff  Summoner         Pre-Boss                    8
# 394    Lightning Aura Rod  Summoner         Pre-Boss                    8
#
#      DPS (MULTI TARGET)  DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# ...

# %% [markdown]
# 5) тут удалось вывести значения столбца "DPS (SINGLE TARGET)" которые меньше 100

# %%
terraria.drop(columns = ["DPS (MULTI TARGET + PROYECTILE ONLY)"])
# Out:
#                    NAME     CLASS GAME PROGRESSION  DPS (SINGLE TARGET)  \
# 0                Zenith     Melee    Post-Moonlord                 4800
# 1            Last Prism      Mage    Post-Moonlord                 3657
# 2            Star Wrath     Melee    Post-Moonlord                 2700
# 3             Terrarian     Melee    Post-Moonlord                 2200
# 4              Meowmere     Melee    Post-Moonlord                 2100
# ..                  ...       ...              ...                  ...
# 390         Paper Plane    Ranger         Pre-Boss                   14
# 391         Finch Staff  Summoner         Pre-Boss                   10
# 392      Flameburst Rod  Summoner         Pre-Boss                    8
# 393         Flinx Staff  Summoner         Pre-Boss                    8
# 394  Lightning Aura Rod  Summoner         Pre-Boss                    8
#
#      DPS (MULTI TARGET)  DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# ...

# %%
terraria.drop(columns = ["DPS (SINGLE TARGET + PROYECTILE ONLY)"])
# Out:
#                    NAME     CLASS GAME PROGRESSION  DPS (SINGLE TARGET)  \
# 0                Zenith     Melee    Post-Moonlord                 4800
# 1            Last Prism      Mage    Post-Moonlord                 3657
# 2            Star Wrath     Melee    Post-Moonlord                 2700
# 3             Terrarian     Melee    Post-Moonlord                 2200
# 4              Meowmere     Melee    Post-Moonlord                 2100
# ..                  ...       ...              ...                  ...
# 390         Paper Plane    Ranger         Pre-Boss                   14
# 391         Finch Staff  Summoner         Pre-Boss                   10
# 392      Flameburst Rod  Summoner         Pre-Boss                    8
# 393         Flinx Staff  Summoner         Pre-Boss                    8
# 394  Lightning Aura Rod  Summoner         Pre-Boss                    8
#
#      DPS (MULTI TARGET)  DPS (MULTI TARGET + PROYECTILE ONLY)  \
# ...

# %%
terraria.drop(labels=[4], axis=0)
# Out:
#                    NAME     CLASS GAME PROGRESSION  DPS (SINGLE TARGET)  \
# 0                Zenith     Melee    Post-Moonlord                 4800
# 1            Last Prism      Mage    Post-Moonlord                 3657
# 2            Star Wrath     Melee    Post-Moonlord                 2700
# 3             Terrarian     Melee    Post-Moonlord                 2200
# 5           Lunar Flare      Mage    Post-Moonlord                 1974
# ..                  ...       ...              ...                  ...
# 390         Paper Plane    Ranger         Pre-Boss                   14
# 391         Finch Staff  Summoner         Pre-Boss                   10
# 392      Flameburst Rod  Summoner         Pre-Boss                    8
# 393         Flinx Staff  Summoner         Pre-Boss                    8
# 394  Lightning Aura Rod  Summoner         Pre-Boss                    8
#
#      DPS (MULTI TARGET)  DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# ...

# %% [markdown]
# 6) во всех этих строчках кода удалось удалить какие либо данные
# (в первом и втором случае - целые столбцы, в третьем - четвертую строчку из всех стаолбцов)

# %%
terraria.rename(columns={'NAME' : 'TITLE'})
# Out:
#                   TITLE     CLASS GAME PROGRESSION  DPS (SINGLE TARGET)  \
# 0                Zenith     Melee    Post-Moonlord                 4800
# 1            Last Prism      Mage    Post-Moonlord                 3657
# 2            Star Wrath     Melee    Post-Moonlord                 2700
# 3             Terrarian     Melee    Post-Moonlord                 2200
# 4              Meowmere     Melee    Post-Moonlord                 2100
# ..                  ...       ...              ...                  ...
# 390         Paper Plane    Ranger         Pre-Boss                   14
# 391         Finch Staff  Summoner         Pre-Boss                   10
# 392      Flameburst Rod  Summoner         Pre-Boss                    8
# 393         Flinx Staff  Summoner         Pre-Boss                    8
# 394  Lightning Aura Rod  Summoner         Pre-Boss                    8
#
#      DPS (MULTI TARGET)  DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# ...

# %% [markdown]
# 7) здесь удалось изменить название столбца с NAME на TITLE

# %%
terraria.drop_duplicates()
# Out:
#                    NAME     CLASS GAME PROGRESSION  DPS (SINGLE TARGET)  \
# 0                Zenith     Melee    Post-Moonlord                 4800
# 1            Last Prism      Mage    Post-Moonlord                 3657
# 2            Star Wrath     Melee    Post-Moonlord                 2700
# 3             Terrarian     Melee    Post-Moonlord                 2200
# 4              Meowmere     Melee    Post-Moonlord                 2100
# ..                  ...       ...              ...                  ...
# 390         Paper Plane    Ranger         Pre-Boss                   14
# 391         Finch Staff  Summoner         Pre-Boss                   10
# 392      Flameburst Rod  Summoner         Pre-Boss                    8
# 393         Flinx Staff  Summoner         Pre-Boss                    8
# 394  Lightning Aura Rod  Summoner         Pre-Boss                    8
#
#      DPS (MULTI TARGET)  DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# ...

# %% [markdown]
# 8) здесь пыталась удалить дубликаты но их не оказалось (но как работает метод я поняла!!!)

# %%
terraria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 8 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   NAME                                   395 non-null    object
#  1   CLASS                                  395 non-null    object
#  2   GAME PROGRESSION                       395 non-null    object
#  3   DPS (SINGLE TARGET)                    395 non-null    int64
#  4   DPS (MULTI TARGET)                     309 non-null    float64
#  5   DPS (SINGLE TARGET + PROYECTILE ONLY)  25 non-null     float64
#  6   DPS (MULTI TARGET + PROYECTILE ONLY)   19 non-null     float64
#  7   OBSERVATIONS                           140 non-null    object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 24.8+ KB

# %% [markdown]
# 9) тут провела анализ датасета с помощью мктода info

# %%
terraria.describe()
# Out:
#        DPS (SINGLE TARGET)  DPS (MULTI TARGET)  \
# count           395.000000          309.000000
# mean            262.273418          651.543689
# std             437.778258         1102.016874
# min               8.000000           17.000000
# 25%              58.000000          150.000000
# 50%             130.000000          350.000000
# 75%             289.000000          771.000000
# max            4800.000000        13000.000000
#
#        DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# count                              25.000000
# mean                              348.600000
# std                               380.502738
# min                                30.000000
# 25%                                80.000000
# 50%                               250.000000
# 75%                               500.000000
# max                              1500.000000
#
#        DPS (MULTI TARGET + PROYECTILE ONLY)
# count                             19.000000
# ...

# %% [markdown]
# 10) тут провела анализ датасета с помощью мктода describe

# %%
subset = terraria.loc[[5, 6, 7], ['NAME', 'CLASS', 'DPS (SINGLE TARGET)']]

# %% [markdown]
# 11) удалось провести выборку данных по строкам и столбцам с помощью loc

# %%
terraria.to_csv("terraria_new.csv", index = False)

# %% [markdown]
# 12) здеся удалось сохранить новый датасет в csv файл

# %% [markdown]
# вывод: удалось провести анализ выбранного датасета
